# %%
import folium
from math import sin, cos, sqrt, atan2, radians

# --- FONCTION DE CALCUL DE DISTANCE (Haversine) ---
def calculate_distance(lat1, lon1, lat2, lon2):
    # Rayon de la Terre en kilomètres
    R = 6373.0

    lat1, lon1 = radians(lat1), radians(lon1)
    lat2, lon2 = radians(lat2), radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return R * c

# --- 1. COORDINATE MARKERS & BASE MAP ---
# Initialisation de la carte centrée sur les États-Unis
nasa_map = folium.Map(location=[28.5623, -80.5774], zoom_start=5)

# Coordonnées réelles des sites de lancement SpaceX
launch_sites = {
    'CCAFS SLC-40': [28.562302, -80.577356],
    'KSC LC-39A': [28.573255, -80.646895],
    'VAFB SLC-4E': [34.632834, -120.610745]
}

# Coordonnées d'une infrastructure critique proche (Exemple : Côte Atlantique)
coastline_coord = [28.56367, -80.56801]

# Ajout des marqueurs et cercles de proximité
for site, coord in launch_sites.items():
    # Marqueur de texte personnalisé
    folium.Marker(
        location=coord,
        popup=site,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(nasa_map)

    # --- 2. PROXIMITY CIRCLES ---
    # Cercles colorés pour évaluer visuellement la zone de sécurité
    folium.Circle(
        location=coord,
        radius=1000, # Rayon de 1 km
        color='#d35400',
        fill=True,
        fill_color='#d35400'
    ).add_to(nasa_map)

# --- 3. DISTANCE POLYLINES & SPATIAL ANALYSIS ---
# Calcul de la distance entre CCAFS SLC-40 et la côte
distance_coast = calculate_distance(launch_sites['CCAFS SLC-40'][0], launch_sites['CCAFS SLC-40'][1], coastline_coord[0], coastline_coord[1])

# Tracé de la ligne interactive entre le pas de tir et la côte
folium.PolyLine(
    locations=[launch_sites['CCAFS SLC-40'], coastline_coord],
    weight=2,
    color='blue'
).add_to(nasa_map)

# Ajout d'une étiquette textuelle indiquant la distance calculée
folium.Marker(
    location=coastline_coord,
    icon=folium.DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html=f'<div style="font-size: 12pt; color:#d35400;"><b>{distance_coast:.2f} KM</b></div>'
    )
).add_to(nasa_map)

# --- AFFICHAGE DE LA CARTE ---
# Note : Dans Google Colab, tapez simplement 'nasa_map' dans la cellule suivante pour l'afficher.
nasa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6a4f923f3fe7a01f464303e36d76366 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6a4f923f3fe7a01f464303e36d76366&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6a4f923f3fe7a01f464303e36d76366 = L.map(
#                 &quot;map_b6a4f923f3fe7a01f464303e36d76366&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f4ba5382ac86e56cdd0eaac5cbda1f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f4ba5382ac86e56cdd0eaac5cbda1f3.addTo(map_b6a4f923f3fe7a01f464303e36d76366);
#
#
#             var marker_891e0911bbc649fcf98abb318772fb47 = L.marker(
#                 [28.562302, -80.577356],
#                 {
# }
#             ).addTo(map_b6a4f923f3fe7a01f464303e36d76366);
#
#
#             var icon_c763aeb55c99daeed2d4c56b99d7beb3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fec5c894fc5dc9670b90ad141c33397a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c5c07c5505b632e6d9ffda2e40e2ddc = $(`&lt;div id=&quot;html_2c5c07c5505b632e6d9ffda2e40e2ddc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_fec5c894fc5dc9670b90ad141c33397a.setContent(html_2c5c07c5505b632e6d9ffda2e40e2ddc);
#
#
#
#         marker_891e0911bbc649fcf98abb318772fb47.bindPopup(popup_fec5c894fc5dc9670b90ad141c33397a)
#         ;
#
#
#
#
#                 marker_891e0911bbc649fcf98abb318772fb47.setIcon(icon_c763aeb55c99daeed2d4c56b99d7beb3);
#
#
#             var circle_5177d298b4cdb1e245fbf66ceb6b5eb4 = L.circle(
#                 [28.562302, -80.577356],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b6a4f923f3fe7a01f464303e36d76366);
#
#
#             var marker_5f3cd3827c460a0202742a48063c4ee3 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_b6a4f923f3fe7a01f464303e36d76366);
#
#
#             var icon_24dc1213ee9ee31cf8e7c47c64212c97 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f05c5c41fec43ee6a30b75d73f195d77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56300e393a3e3a2bf83cebe3ecab18cd = $(`&lt;div id=&quot;html_56300e393a3e3a2bf83cebe3ecab18cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_f05c5c41fec43ee6a30b75d73f195d77.setContent(html_56300e393a3e3a2bf83cebe3ecab18cd);
#
#
#
#         marker_5f3cd3827c460a0202742a48063c4ee3.bindPopup(popup_f05c5c41fec43ee6a30b75d73f195d77)
#         ;
#
#
#
#
#                 marker_5f3cd3827c460a0202742a48063c4ee3.setIcon(icon_24dc1213ee9ee31cf8e7c47c64212c97);
#
#
#             var circle_362a2688cf0bf36ab6ace8cf431b880d = L.circle(
#                 [28.573255, -80.646895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b6a4f923f3fe7a01f464303e36d76366);
